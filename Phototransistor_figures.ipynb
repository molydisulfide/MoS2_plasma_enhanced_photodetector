# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
import matplotlib.colors as colors
import seaborn as sns
import pandas as pd

# %%
gate = []
gtpre_0 = []
gtpre_0001  = []
gtpre_005  = []
gtpre_01 = []
gtpre_05 = []
gtpre_1 = []


with open('gate_pre.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        gate.append(float(row[0]))
        gtpre_0.append(float(row[1]))
        gtpre_0001.append(float(row[2]))
        gtpre_005.append(float(row[3]))
        gtpre_01.append(float(row[4]))
        gtpre_05.append(float(row[5]))
        gtpre_1.append(float(row[6]))

# %%
time = []
nm488_005 = []
nm488_05  = []
nm488_1  = []
nm632_005 = []
nm632_05 = []
nm632_1 = []


with open('time_before.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        time.append(float(row[0]))
        nm488_005.append(float(row[1]))
        nm488_05.append(float(row[2]))
        nm488_1.append(float(row[3]))
        nm632_005.append(float(row[4]))
        nm632_05.append(float(row[5]))
        nm632_1.append(float(row[6]))

# %%
gatepost = []
gtpost_0 = []
gtpost_0001  = []
gtpost_005  = []
gtpost_01 = []
gtpost_05 = []
gtpost_1 = []


with open('gate_post.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        gatepost.append(float(row[0]))
        gtpost_0.append(float(row[1]))
        gtpost_0001.append(float(row[2]))
        gtpost_005.append(float(row[3]))
        gtpost_01.append(float(row[4]))
        gtpost_05.append(float(row[5]))
        gtpost_1.append(float(row[6]))

# %%
iv = []
ivpre_0 = []
ivpre_0001  = []
ivpre_005  = []
ivpre_01 = []
ivpre_05 = []
ivpre_1 = []


with open('IV_pre.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        iv.append(float(row[0]))
        ivpre_0.append(float(row[1]))
        ivpre_0001.append(float(row[2]))
        ivpre_005.append(float(row[3]))
        ivpre_01.append(float(row[4]))
        ivpre_05.append(float(row[5]))
        ivpre_1.append(float(row[6]))

# %%
ivpost = []
ivpost_0 = []
ivpost_0001  = []
ivpost_005  = []
ivpost_01 = []
ivpost_05 = []
ivpost_1 = []


with open('IV_post.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        ivpost.append(float(row[0]))
        ivpost_0.append(float(row[1]))
        ivpost_0001.append(float(row[2]))
        ivpost_005.append(float(row[3]))
        ivpost_01.append(float(row[4]))
        ivpost_05.append(float(row[5]))
        ivpost_1.append(float(row[6]))

# %%
power = []
mob_pre = []
mob_post  = []
I_pre  = []
I_post = []


with open('mobility_488.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        power.append(float(row[0]))
        mob_pre.append(float(row[1]))
        mob_post.append(float(row[2]))
        I_pre.append(float(row[3]))
        I_post.append(float(row[4]))

# %%
power1 = []
mob_pre1 = []
mob_post1  = []
I_pre1  = []
I_post1 = []


with open('mobility_632.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        power1.append(float(row[0]))
        mob_pre1.append(float(row[1]))
        mob_post1.append(float(row[2]))
        I_pre1.append(float(row[3]))
        I_post1.append(float(row[4]))

# %%
time_632_tau_rise = []
_632_tau_rise = []
time_632 = []
pre_632  = []
post_632  = []
time_632_tau_fall = []
_632_tau_fall = []



with open('632comparison.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        time_632_tau_rise.append(float(row[0]))
        _632_tau_rise.append(float(row[1]))
        time_632.append(float(row[2]))
        pre_632.append(float(row[3]))
        post_632.append(float(row[4]))
        time_632_tau_fall.append(float(row[5]))
        _632_tau_fall.append(float(row[6]))

# %%
time_632_tau = []
tau_afterplasma_rise = []




with open('tau_afterplasma_rise.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        time_632_tau.append(float(row[0]))
        tau_afterplasma_rise.append(float(row[1]))

# %%
time_488 = []
pre_488 = []
post_488  = []



with open('488comparison.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        time_488.append(float(row[0]))
        pre_488.append(float(row[1]))
        post_488.append(float(row[2]))

# %%
power_632_before = []
before_632_gate_neg_60 = []
before_632_gate_0 = []
before_632_gate_60 = []



with open('r_ph_632_before.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        power_632_before.append(float(row[0]))
        before_632_gate_neg_60 .append(float(row[1]))
        before_632_gate_0.append(float(row[2]))
        before_632_gate_60.append(float(row[3]))

# %%
power_632_a = []
a_632_gate_neg_60 = []
a_632_gate_0 = []
a_632_gate_60 = []



with open('r_ph_632_after.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        power_632_a.append(float(row[0]))
        a_632_gate_neg_60 .append(float(row[1]))
        a_632_gate_0.append(float(row[2]))
        a_632_gate_60.append(float(row[3]))

# %%
fit_x = []
fit_y1 = []
fit_y2 = []
fit_y3 = []



with open('r_ph_fits_after.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        fit_x.append(float(row[0]))
        fit_y1.append(float(row[1]))
        fit_y2.append(float(row[2]))
        fit_y3.append(float(row[3]))

# %%
fit_xb = []
fit_y1b = []
fit_y2b = []
fit_y3b = []



with open('r_ph_fits_before.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        fit_xb.append(float(row[0]))
        fit_y1b.append(float(row[1]))
        fit_y2b.append(float(row[2]))
        fit_y3b.append(float(row[3]))

# %%
fig = plt.figure(figsize=(8,8))
fig.canvas.draw()

sns.set_style('ticks')

ax1 = fig.add_subplot(221, axisbg="#E8DDCB")
ax1.plot(iv,ivpre_0 , '-', ms=10, color = 'black',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
              label = 'Dark' ) 
ax1.plot(iv,ivpre_0001 , '-', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '7.2 nW' ) 
ax1.plot(iv,ivpre_005 , '-', ms=10, color = 'b',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '3.6 $\mu$W' ) 
ax1.plot(iv,ivpre_01 , '-', ms=10, color = 'orange',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '7.2 $\mu$W' ) 
ax1.plot(iv,ivpre_05 , '-', ms=10, color = 'yellow',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '36 $\mu$W' ) 
ax1.plot(iv,ivpre_1 , '-', ms=10, color = '#036564',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '72 $\mu$W' ) 

ax1.grid('on')
ax1.set_title('(a)')

ax2 = fig.add_subplot(222, axisbg="#E8DDCB")
ax2.plot(gate,gtpre_0 , '-', ms=10, color = 'black',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
              label = 'Dark' ) 
ax2.plot(gate,gtpre_0001 , '-', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '7.2 nW' ) 
ax2.plot(gate,gtpre_005 , '-', ms=10, color = 'b',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '3.6 $\mu$W' ) 
ax2.plot(gate,gtpre_01 , '-', ms=10, color = 'orange',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '7.2 $\mu$W' ) 
ax2.plot(gate,gtpre_05 , '-', ms=10, color = 'yellow',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '36 $\mu$W' ) 
ax2.plot(gate,gtpre_1 , '-', ms=10, color = '#036564',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '72 $\mu$W' ) 
ax2.grid('on')

ax2.set_title('(b)')

ax3 = fig.add_subplot(223, axisbg="#E8DDCB")
ax3.plot(ivpost,ivpost_0 , '-', ms=10, color = 'black',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
              label = 'Dark' ) 
ax3.plot(ivpost,ivpost_0001 , '-', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '7.2 nW' ) 
ax3.plot(ivpost,ivpost_005 , '-', ms=10, color = 'b',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '3.6 $\mu$W' ) 
ax3.plot(ivpost,ivpost_01 , '-', ms=10, color = 'orange',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '7.2 $\mu$W' ) 
ax3.plot(ivpost,ivpost_05 , '-', ms=10, color = 'yellow',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '36 $\mu$W' ) 
ax3.plot(ivpost,ivpost_1 , '-', ms=10, color = '#036564',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '72 $\mu$W' ) 

ax3.grid('on')

ax3.set_title('(c)')

ax4 = fig.add_subplot(224, axisbg="#E8DDCB")
ax4.plot(gate,gtpost_0 , '-', ms=10, color = 'black',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
              label = 'Dark' ) 
ax4.plot(gate,gtpost_0001 , '-', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '7.2 nW' ) 
ax4.plot(gate,gtpost_005 , '-', ms=10, color = 'b',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '3.6 $\mu$W' ) 
ax4.plot(gate,gtpost_01 , '-', ms=10, color = 'orange',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '7.2 $\mu$W' ) 
ax4.plot(gate,gtpost_05 , '-', ms=10, color = 'yellow',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '36 $\mu$W' ) 
ax4.plot(gate,gtpost_1 , '-', ms=10, color = '#036564',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '72 $\mu$W' ) 
ax4.grid('on')

ax4.set_title('(d)')

ax1.set_ylabel('$I_{DS}$ ($\mu$A)', fontsize = 12)
ax3.set_xlabel('V$_{DS}$ (V)', fontsize = 12)
ax3.set_ylabel('$I_{DS}$ ($\mu$A)', fontsize = 12)
ax2.set_ylabel('$I_{DS}$ (A)', fontsize = 12)
ax4.set_ylabel('$I_{DS}$ (A)', fontsize = 12)
ax4.set_xlabel('V$_{GS}$ (V)', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('right')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('right')

plt.ticklabel_format(style='sci', axis='y')
#plt.ticklabel_format(style='sci', axis='x')
#ax1.set_yscale('log')
ax2.set_yscale('log')
#ax3.set_yscale('log')
ax4.set_yscale('log')


#ax1.set_ylim([0.01,100])
#ax2.set_ylim([0.00000001,0.00001])
ax3.set_ylim([-20,25])
#ax4.set_ylim([0.00000001,0.00001])
ax1.set_xlim([-5,5])
ax2.set_xlim([-60,60])
ax3.set_xlim([-5,5])
ax4.set_xlim([-60,60])

#major_ticks_1 = np.arange(0.004, 0.012, 0.002)   
#ax4.set_xticks(major_ticks_1) 
#ax2.set_xticks(major_ticks_1)
#ax1.legend(loc = 'lower right', ncol = 2, fontsize=11)
ax2.legend(loc = 'lower right', ncol = 1, fontsize=12)
#ax3.legend(loc = 'lower right', ncol = 2, fontsize=11)
#ax4.legend(loc = 'lower right', ncol = 2, fontsize=11)
plt.savefig("Fig_1",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(8,8))
fig.canvas.draw()

sns.set_style('ticks')

ax1 = fig.add_subplot(221, axisbg="#E8DDCB")
ax1.plot(power,mob_pre, '-o', ms=10, color = '#036564', lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', label = 'Pre-plasma' ) 
ax1.plot(power,mob_post, '-^', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Post-plasma' ) 

ax1.grid('on')
ax1.set_title('(a)')

ax2 = fig.add_subplot(222, axisbg="#E8DDCB")
ax2.plot(power,I_pre , '-o', ms=10, color = '#036564',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
              label = 'Pre-plasma' ) 
ax2.plot(power,I_post , '-^', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Post-plasma' ) 
ax2.grid('on')

ax2.set_title('(b)')

ax3 = fig.add_subplot(223, axisbg="#E8DDCB")
ax3.plot(power1,mob_pre1 , '-o', ms=10, color = '#036564',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
              label = 'Pre-plasma' ) 
ax3.plot(power1,mob_post1 , '-^', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Post-plasma' ) 

ax3.grid('on')
ax3.set_title('(c)')

ax4 = fig.add_subplot(224, axisbg="#E8DDCB")
ax4.plot(power1,I_pre1 , '-o', ms=10, color = '#036564',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
              label = 'Pre-plasma' ) 
ax4.plot(power1,I_post1 , '-^', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Post-plasma' ) 
ax4.grid('on')
ax4.set_title('(d)')

ax1.set_ylabel('$\mu_{fe}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
ax2.set_ylabel('$I_{DS}$ (A)', fontsize = 12)
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position("right")
ax4.yaxis.tick_right()
ax4.yaxis.set_label_position("right")
ax4.set_ylabel('$I_{DS}$ (A)', fontsize = 12)
ax3.set_xlabel('Laser power (mW)', fontsize = 12)
ax3.set_ylabel('$\mu_{fe}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
ax4.set_xlabel('Laser power (mW)', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('right')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('right')

plt.ticklabel_format(style='sci', axis='y')
plt.ticklabel_format(style='sci', axis='x')
ax1.set_yscale('log')
ax2.set_yscale('log')
ax3.set_yscale('log')
ax4.set_yscale('log')
ax1.set_xscale('log')
ax2.set_xscale('log')
ax3.set_xscale('log')
ax4.set_xscale('log')

ax1.set_ylim([0.01,100])
ax2.set_ylim([0.00000001,0.00001])
ax3.set_ylim([0.01,100])
ax4.set_ylim([0.00000001,0.00001])
ax1.set_xlim([0.000001,1])
ax2.set_xlim([0.000001,1])
ax3.set_xlim([0.000001,1])
ax4.set_xlim([0.000001,1])

#major_ticks_1 = np.arange(0.004, 0.012, 0.002)   
#ax4.set_xticks(major_ticks_1) 
#ax2.set_xticks(major_ticks_1)
ax1.legend(loc = 'lower right', ncol = 1, fontsize=12)
ax2.legend(loc = 'lower right', ncol = 1, fontsize=12)
ax3.legend(loc = 'lower right', ncol = 1, fontsize=12)
ax4.legend(loc = 'lower right', ncol = 1, fontsize=12)
plt.savefig("mobility",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(12,4))
fig.canvas.draw()

sns.set_style('ticks')

ax1 = fig.add_subplot(221, axisbg="#E8DDCB")
ax1.plot(time,nm488_005 , '-', ms=10, color = '#036564',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
              label = '3.6 $\mu$W' ) 
ax1.plot(time,nm488_05 , '-', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '7.2 $\mu$W' ) 
ax1.plot(time,nm488_1 , '-', ms=10, color = 'b',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '36 $\mu$W' ) 


ax1.grid('on')
ax1.set_title('(a)')

ax2 = fig.add_subplot(222, axisbg="#E8DDCB")
ax2.plot(time,nm632_005 , '-', ms=10, color = '#036564',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '7.2 $\mu$W' ) 
ax2.plot(time,nm632_05 , '-', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '36 $\mu$W' ) 
ax2.plot(time,nm632_1 , '-', ms=10, color = 'b',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '72 $\mu$W' ) 
ax2.grid('on')

ax2.set_title('(b)')

ax3 = fig.add_subplot(223, axisbg="#E8DDCB")
ax3.plot(time_632,pre_632 , '-', ms=10, color = 'indigo',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
              label = 'Pre' ) 
ax3.plot(time_632,post_632 , '-', ms=10, color = 'limegreen',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Post' ) 
ax3.grid('on')

ax3.set_title('(c)')
ax4 = fig.add_subplot(224, axisbg="#E8DDCB")
ax4.plot(time_488,pre_488 , '-', ms=10, color = 'indigo',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
              label = 'Pre' ) 
ax4.plot(time_488,post_488 , '-', ms=10, color = 'limegreen',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Post' ) 


ax4.grid('on')

ax4.set_title('(d)')




ax1.set_ylabel('$I_{DS}$ (A)', fontsize = 12)
ax3.set_xlabel('Time (s)', fontsize = 12)
ax3.set_ylabel('$I_{DS}$ ($\mu$A)', fontsize = 12)
#ax2.set_ylabel('$I_{DS}$ (A)', fontsize = 12)
#ax4.set_ylabel('$I_{DS}$ (A)', fontsize = 12)
ax4.set_xlabel('Time(s)', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

plt.ticklabel_format(style='sci', axis='y')
#plt.ticklabel_format(style='sci', axis='x')
ax1.set_yscale('log')
ax2.set_yscale('log')
#ax3.set_yscale('log')
#ax4.set_yscale('log')


ax1.set_ylim([0.0000003,0.00005])
ax2.set_ylim([0.0000003,0.000012])
#ax3.set_ylim([-20,25])
#ax4.set_ylim([0.00000001,0.00001])
ax1.set_xlim([25,65])
ax2.set_xlim([25,75])
ax3.set_xlim([20,65])
ax4.set_xlim([0,50])

#major_ticks_1 = np.arange(0.004, 0.012, 0.002)   
#ax4.set_xticks(major_ticks_1) 
#ax2.set_xticks(major_ticks_1)
ax1.legend(loc = 'upper left', ncol = 3, fontsize=10)
#ax2.legend(loc = 'lower right', ncol = 1, fontsize=12)
#ax3.legend(loc = 'lower right', ncol = 2, fontsize=11)
ax4.legend(loc = 'upper left', ncol = 2, fontsize=10)
plt.savefig("time",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(2,4))
fig.canvas.draw()

sns.set_style('ticks')

ax1 = fig.add_subplot(111, axisbg="#E8DDCB")
#ax1.plot(time_632,pre_632 , 'o', ms=5, color = '#036564',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
 #             label = 'Pre-plasma' ) 
ax1.plot(time_632,post_632 , 'o', ms=5, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Raw data' ) 
ax1.plot(time_632_tau_rise,_632_tau_rise , '-', ms=5, color = 'black',  lw=2, alpha=1, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Exp. fit' ) 



ax1.grid('on')
ax1.set_title('(c)')




#ax1.set_ylabel('$I_{DS}$ ($\mu$A)', fontsize = 12)
#ax1.set_xlabel('Time (s)', fontsize = 12)


plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1.get_yticklabels(), visible=False)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('right')


plt.ticklabel_format(style='sci', axis='y')
#plt.ticklabel_format(style='sci', axis='x')
#ax1.set_yscale('log')


ax1.set_ylim([6,15])

ax1.set_xlim([28,34])



x_ticks_labels = ['0','5','10','15','20']


ax1.legend(loc = 'lower right', ncol = 1, fontsize=9)

plt.savefig("tau_rise_afterplasma",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(2,4))
fig.canvas.draw()

sns.set_style('ticks')

ax1 = fig.add_subplot(111, axisbg="#E8DDCB")
#ax1.plot(time_632,pre_632 , 'o', ms=5, color = '#036564',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
 #            label = 'Pre-plasma' ) 
ax1.plot(time_632,post_632 , 'o', ms=5, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Raw data' ) 
ax1.plot(time_632_tau_fall,_632_tau_fall , '-', ms=5, color = 'black',  lw=2, alpha=1, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Exp. fit' ) 



ax1.grid('on')
ax1.set_title('(b)')




#ax1.set_ylabel('$I_{DS}$ ($\mu$A)', fontsize = 12)
#ax1.set_xlabel('Time (s)', fontsize = 12)


plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1.get_yticklabels(), visible=False)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('right')


plt.ticklabel_format(style='sci', axis='y')
#plt.ticklabel_format(style='sci', axis='x')
#ax1.set_yscale('log')


ax1.set_ylim([0,15])

ax1.set_xlim([24,27])



x_ticks_labels = ['0','5','10','15','20']


ax1.legend(loc = 'center right', ncol = 1, fontsize=9)

plt.savefig("tau_fall_afterplasma",bbox_inches='tight', dpi = 300)


plt.show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# MatPlotlib
import matplotlib.pyplot as plt
from matplotlib import pylab

# Scientific libraries
import numpy as np
from scipy.optimize import curve_fit



x = np.array([399.75, 989.25, 1578.75, 2168.25, 2757.75, 3347.25, 3936.75, 4526.25, 5115.75, 5705.25])
y = np.array([109,62,39,13,10,4,2,0,1,2])

def exponenial_func(x, a, b, c):
    return a*np.exp(-b*x)+c


popt, pcov = curve_fit(exponenial_func, x, y, p0=(1, 1e-6, 1))

xx = np.linspace(300, 6000, 1000)
yy = exponenial_func(xx, *popt)

plt.plot(x,y,'o', xx, yy)
pylab.title('Exponential Fit')
ax = plt.gca()
ax.set_axis_bgcolor((0.898, 0.898, 0.898))
fig = plt.gcf()
py.plot_mpl(fig, filename='Exponential-Fit-with-matplotlib')
# Out:
# 'https://plot.ly/~molydisulfide/19'

# %%
power_632_before = []
before_632_gate_neg_60 = []
before_632_gate_0 = []
before_632_gate_60 = []

# %%
fig = plt.figure(figsize=(2,4))
fig.canvas.draw()

sns.set_style('ticks')

ax1 = fig.add_subplot(111, axisbg="#E8DDCB")
ax1.plot(power_632_before,before_632_gate_neg_60 , 'o', ms=7, color = '#036564',  lw=2, alpha=0.7, mfc='b', dash_capstyle = 'butt', mew = '1', 
            label = '-60 V' ) 
ax1.plot(power_632_before,before_632_gate_0 , 's', ms=7, color = '#036564',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
            label = '0 V' )  
ax1.plot(power_632_before,before_632_gate_60 , '^', ms=7, color = '#036564',  lw=2, alpha=0.7, mfc='r', dash_capstyle = 'butt', mew = '1', 
            label = '60 V' )  
ax1.plot(fit_xb,fit_y1b , '-', ms=7, color = 'b',  lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1') 
ax1.plot(fit_xb,fit_y2b , '-', ms=7, color = '#036564',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1')  
ax1.plot(fit_xb,fit_y3b , '-', ms=7, color = 'r',  lw=2, alpha=0.7, mfc='r', dash_capstyle = 'butt', mew = '1' )  


ax1.grid('on')
ax1.set_title('(a)')




ax1.set_ylabel('Photoresponsivity (A/W)', fontsize = 12)
ax1.set_xlabel('Laser power (W)', fontsize = 12)


plt.setp(ax1.get_xticklabels(), visible=True)
plt.setp(ax1.get_yticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')


plt.ticklabel_format(style='sci', axis='y')
#plt.ticklabel_format(style='sci', axis='x')
ax1.set_yscale('log')
ax1.set_xscale('log')


ax1.set_ylim([0.001,450])

ax1.set_xlim([0.000000001,0.0005])





ax1.legend(loc = 'upper right', ncol = 1, fontsize=9)

plt.savefig("r_ph_632_before",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(2,4))
fig.canvas.draw()

sns.set_style('ticks')

ax1 = fig.add_subplot(111, axisbg="#E8DDCB")
ax1.plot(power_632_a,a_632_gate_neg_60 , 'o', ms=7, color = '#036564',  lw=2, alpha=0.7, mfc='b', dash_capstyle = 'butt', mew = '1', 
            label = '-60 V' ) 
ax1.plot(power_632_a,a_632_gate_0 , 's', ms=7, color = '#036564',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
            label = '0 V' )  
ax1.plot(power_632_a,a_632_gate_60 , '^', ms=7, color = '#036564',  lw=2, alpha=0.7, mfc='r', dash_capstyle = 'butt', mew = '1', 
            label = '60 V' )  
ax1.plot(fit_x,fit_y1 , '-', ms=7, color = 'b',  lw=2, alpha=0.7, mfc='yellow', dash_capstyle = 'butt', mew = '1') 
ax1.plot(fit_x,fit_y2 , '-', ms=7, color = '#036564',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1')  
ax1.plot(fit_x,fit_y3 , '-', ms=7, color = 'r',  lw=2, alpha=0.7, mfc='r', dash_capstyle = 'butt', mew = '1' )  


ax1.grid('on')
ax1.set_title('(b)')




#ax1.set_ylabel('Photoresponsivity (A/W)', fontsize = 12)
ax1.set_xlabel('Laser power (W)', fontsize = 12)


plt.setp(ax1.get_xticklabels(), visible=True)
plt.setp(ax1.get_yticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')


plt.ticklabel_format(style='sci', axis='y')
#plt.ticklabel_format(style='sci', axis='x')
ax1.set_yscale('log')
ax1.set_xscale('log')


ax1.set_ylim([0.001,450])

ax1.set_xlim([0.000000001,0.0005])





ax1.legend(loc = 'upper right', ncol = 1, fontsize=9)

plt.savefig("r_ph_632_after",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(2,4))
fig.canvas.draw()

sns.set_style('ticks')

ax1 = fig.add_subplot(111, axisbg="#E8DDCB")
#ax1.plot(time_632,pre_632 , 'o', ms=5, color = '#036564',  lw=2, alpha=0.7, mfc='#036564', dash_capstyle = 'butt', mew = '1', 
 #             label = 'Pre-plasma' ) 
ax1.plot(time_632,post_632 , 'o', ms=5, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Raw data' ) 
ax1.plot(time_632_tau_rise,_632_tau_rise , '-', ms=5, color = 'black',  lw=2, alpha=1, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = 'Exp. fit' ) 



ax1.grid('on')
ax1.set_title('(c)')




#ax1.set_ylabel('$I_{DS}$ ($\mu$A)', fontsize = 12)
#ax1.set_xlabel('Time (s)', fontsize = 12)


plt.setp(ax1.get_xticklabels(), visible=True)
plt.setp(ax1.get_yticklabels(), visible=False)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('right')


plt.ticklabel_format(style='sci', axis='y')
#plt.ticklabel_format(style='sci', axis='x')
#ax1.set_yscale('log')


ax1.set_ylim([6,15])

ax1.set_xlim([13,19])



x_ticks_labels = ['0','5','10','15','20']


ax1.legend(loc = 'lower right', ncol = 1, fontsize=9)

plt.savefig("ticks",bbox_inches='tight', dpi = 300)


plt.show()
